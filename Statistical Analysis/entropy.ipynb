# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
CSV_FILE_NAME = 'qwen2.5_7b_results.csv' 
COLUMN_NAME = 'entropy_new'
try:
    df = pd.read_csv(CSV_FILE_NAME)
    if COLUMN_NAME not in df.columns:
        print(f"Error: Column '{COLUMN_NAME}' not found in {CSV_FILE_NAME}.")
        print(f"Available columns are: {df.columns.tolist()}")
    else:
        plt.figure(figsize=(10, 6)) 
        sns.histplot(data=df, x=COLUMN_NAME, kde=True, bins=30)
        plt.title(f'Distribution of {COLUMN_NAME}', fontsize=16)
        plt.xlabel('Entropy Value', fontsize=12)
        plt.ylabel('Frequency (Count)', fontsize=12)
        plt.show()

except FileNotFoundError:
    print(f"Error: The file '{CSV_FILE_NAME}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
CSV_FILE_NAME = 'sampled_human_texts.csv'  
COLUMN_NAME = 'entropy_new' 
try:
    df = pd.read_csv(CSV_FILE_NAME)
    if COLUMN_NAME not in df.columns:
        print(f"Error: Column '{COLUMN_NAME}' not found in {CSV_FILE_NAME}.")
        print(f"Available columns are: {df.columns.tolist()}")
    else:
        plt.figure(figsize=(10, 6))
        sns.histplot(data=df, x=COLUMN_NAME, kde=True, bins=30)
        plt.title(f'Distribution of {COLUMN_NAME}', fontsize=16)
        plt.xlabel('Entropy Value', fontsize=12)
        plt.ylabel('Frequency (Count)', fontsize=12)
        plt.show()

except FileNotFoundError:
    print(f"Error: The file '{CSV_FILE_NAME}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
CSV_FILE_NAME = 'llama3.2_3b_results.csv'  
COLUMN_NAME = 'entropy_new' 
try:
    df = pd.read_csv(CSV_FILE_NAME)
    if COLUMN_NAME not in df.columns:
        print(f"Error: Column '{COLUMN_NAME}' not found in {CSV_FILE_NAME}.")
        print(f"Available columns are: {df.columns.tolist()}")
    else:
        plt.figure(figsize=(10, 6))
        sns.histplot(data=df, x=COLUMN_NAME, kde=True, bins=30)
        plt.title(f'Distribution of {COLUMN_NAME}', fontsize=16)
        plt.xlabel('Entropy Value', fontsize=12)
        plt.ylabel('Frequency (Count)', fontsize=12)
        plt.show()

except FileNotFoundError:
    print(f"Error: The file '{CSV_FILE_NAME}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
CSV_FILE_NAME = 'sampled_human_texts.csv' 
COLUMN_NAME = 'entropy_new' 

try:
    df = pd.read_csv(CSV_FILE_NAME)
    if COLUMN_NAME not in df.columns:
        print(f"Error: Column '{COLUMN_NAME}' not found in {CSV_FILE_NAME}.")
        print(f"Available columns are: {df.columns.tolist()}")
    else:
        plt.figure(figsize=(10, 6))
        sns.histplot(data=df, x=COLUMN_NAME, kde=True, bins=30, stat='density')
        plt.title(f'Density Plot of {COLUMN_NAME}', fontsize=16)
        plt.xlabel('Entropy Value', fontsize=12)
        plt.ylabel('Density', fontsize=12) 
        output_filename = 'entropy_density_plot.png'
        plt.savefig(output_filename)
        print(f"Plot saved successfully as '{output_filename}'")

except FileNotFoundError:
    print(f"Error: The file '{CSV_FILE_NAME}' was not found.")
    print("Please upload the file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Plot saved successfully as 'entropy_density_plot.png'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
CSV_FILE_NAME = 'sampled_human_texts.csv' 
COLUMN_NAME = 'entropy_new' 

try:
    df = pd.read_csv(CSV_FILE_NAME)
    if COLUMN_NAME not in df.columns:
        print(f"Error: Column '{COLUMN_NAME}' not found in {CSV_FILE_NAME}.")
        print(f"Available columns are: {df.columns.tolist()}")
    else:
        plt.figure(figsize=(10, 6))
        sns.histplot(data=df, x=COLUMN_NAME, kde=True, bins=30, stat='density')
        plt.title(f'Density Plot of {COLUMN_NAME}', fontsize=16)
        plt.xlabel('Entropy Value', fontsize=12)
        plt.ylabel('Density', fontsize=12) 
        output_filename = 'entropy_density_plot.png'
        plt.savefig(output_filename)
        print(f"Plot saved successfully as '{output_filename}'")

except FileNotFoundError:
    print(f"Error: The file '{CSV_FILE_NAME}' was not found.")
    print("Please upload the file.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
import pandas as pd
import os
INPUT_JSON_FILE = 'gpt4-pub-gpt3.5.json' 

OUTPUT_CSV_0 = 'result_0_texts.csv'
OUTPUT_CSV_1 = 'result_1_texts.csv'
if not os.path.exists(INPUT_JSON_FILE):
    print(f"Error: File not found: '{INPUT_JSON_FILE}'")
    print("Please make sure the file is in the same directory and the name is correct.")
else:
    try:
        df = pd.read_json(INPUT_JSON_FILE)
    
    except ValueError:
        try:
            print("Standard JSON read failed, trying JSONL format (one object per line)...")
            df = pd.read_json(INPUT_JSON_FILE, lines=True)
        
        except Exception as e:
            print(f"Error: Could not parse JSON file. File might be malformed.")
            print(f"Details: {e}")
            df = None

    if df is not None:
        try:
            if 'result' not in df.columns or 'text' not in df.columns:
                print(f"Error: 'result' or 'text' column not found in the file.")
                print(f"Available columns are: {df.columns.tolist()}")
            else:
                df_result_0 = df[df['result'] == '0']
                df_result_1 = df[df['result'] == '1']
                df_result_0['text'].to_csv(OUTPUT_CSV_0, index=False, header=['text'])
                df_result_1['text'].to_csv(OUTPUT_CSV_1, index=False, header=['text'])

                print(f"Successfully processed {len(df)} records.")
                print(f"Saved {len(df_result_0)} records to '{OUTPUT_CSV_0}'")
                print(f"Saved {len(df_result_1)} records to '{OUTPUT_CSV_1}'")
        
        except Exception as e:
            print(f"An error occurred during filtering or saving: {e}")
# Out:
# Successfully processed 298 records.
# Saved 0 records to 'result_0_texts.csv'
# Saved 0 records to 'result_1_texts.csv'

# %%
INPUT_JSON_FILE = 'gpt4-pub-gpt3.5.json'
df = pd.read_json(INPUT_JSON_FILE)

# %%
df.head()
# Out:
#                                                 text  result
# 0  An advance care planning model is feasible for...       0
# 1  Yes, an advance care planning model is feasibl...       1
# 2  Long-term dietary compliance in screen-detecte...       0
# 3  Yes, coeliac disease screening in risk groups ...       1
# 4  Systolic BP measured by the nurse in treated h...       0

# %%
import pandas as pd
import os
import json
INPUT_JSON_FILE = 'gpt4-writing-gpt3.5.json'
OUTPUT_CSV_0 = 'result_0_texts0.csv'
OUTPUT_CSV_1 = 'result_1_texts1.csv'
if not os.path.exists(INPUT_JSON_FILE):
    print(f" File not found: {INPUT_JSON_FILE}")
else:
    df = None
    try:
        with open(INPUT_JSON_FILE, 'r', encoding='utf-8') as f:
            data = json.load(f)
        df = pd.DataFrame(data)
    except json.JSONDecodeError:
        try:
            df = pd.read_json(INPUT_JSON_FILE, lines=True)
        except Exception as e:
            print(" Could not parse JSON or JSONL:", e)

    if df is not None:
        df['result'] = df['result'].astype(str)
        df_result_0 = df[df['result'] == '0']
        df_result_1 = df[df['result'] == '1']
        df_result_0[['text']].to_csv(OUTPUT_CSV_0, index=False)
        df_result_1[['text']].to_csv(OUTPUT_CSV_1, index=False)
# Out:
# ✅ Total records: 300
# ✅ Saved 150 records → result_0_texts0.csv
# ✅ Saved 150 records → result_1_texts1.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
CSV_FILE_NAME = 'result_0_texts0.csv' 
COLUMN_NAME = 'entropy_new' 

try:
    df = pd.read_csv(CSV_FILE_NAME)
    if COLUMN_NAME not in df.columns:
        print(f"Error: Column '{COLUMN_NAME}' not found in {CSV_FILE_NAME}.")
        print(f"Available columns are: {df.columns.tolist()}")
    else:
        plt.figure(figsize=(10, 6))
        sns.histplot(data=df, x=COLUMN_NAME, kde=True, bins=30, stat='density')
        plt.title(f'Density Plot of {COLUMN_NAME}', fontsize=16)
        plt.xlabel('Entropy Value', fontsize=12)
        plt.ylabel('Density', fontsize=12)
        
        output_filename = 'entropy_density_plot.png'
        plt.savefig(output_filename)
        print(f"Plot saved successfully as '{output_filename}'")

except FileNotFoundError:
    print(f"Error: The file '{CSV_FILE_NAME}' was not found.")
    print("Please upload the file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Plot saved successfully as 'entropy_density_plot.png'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
CSV_FILE_NAME = 'result_1_texts1.csv' 
COLUMN_NAME = 'entropy_new'

try:
    df = pd.read_csv(CSV_FILE_NAME)

    if COLUMN_NAME not in df.columns:
        print(f"Error: Column '{COLUMN_NAME}' not found in {CSV_FILE_NAME}.")
        print(f"Available columns are: {df.columns.tolist()}")
    else:
        plt.figure(figsize=(10, 6))
        sns.histplot(data=df, x=COLUMN_NAME, kde=True, bins=30, stat='density')
        
        plt.title(f'Density Plot of {COLUMN_NAME}', fontsize=16)
        plt.xlabel('Entropy Value', fontsize=12)
        plt.ylabel('Density', fontsize=12)
        output_filename = 'entropy_density_plot.png'
        plt.savefig(output_filename)
        print(f"Plot saved successfully as '{output_filename}'")

except FileNotFoundError:
    print(f"Error: The file '{CSV_FILE_NAME}' was not found.")
    print("Please upload the file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Plot saved successfully as 'entropy_density_plot.png'

# %%
import os
import math
import torch
import pandas as pd
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForCausalLM

MODEL_NAME = "gpt2"
MAX_LENGTH = 256

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME).to(device)
model.eval()

@torch.no_grad()
def sequence_entropy(text, use_device):
    if not text or not isinstance(text, str):
        return 0.0

    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=MAX_LENGTH)
    inputs = {k: v.to(use_device) for k, v in inputs.items()}
    input_ids = inputs["input_ids"]
    seq_len = input_ids.size(1)
    if seq_len <= 1:
        return 0.0

    entropies = []
    for i in range(1, seq_len):
        logits = model(input_ids[:, :i]).logits[:, -1, :]
        probs = torch.softmax(logits, dim=-1)
        entropy = -torch.sum(probs * torch.log2(probs + 1e-12), dim=-1)
        entropies.append(float(entropy.cpu().item()))
    return sum(entropies) / len(entropies)

input_path = "/content/sampled_human_texts (1).csv"
output_path = input_path  # saving into same file is supported by the code below

df = pd.read_csv(input_path)

if "entropy_new" not in df.columns:
    df["entropy_new"] = pd.NA

rows_to_process = df[df["entropy_new"].isna()].index.tolist()

for idx in tqdm(rows_to_process, dynamic_ncols=True):
    text = df.at[idx, "text"]
    try:
        ent = sequence_entropy(text, device)
    except Exception:
        try:
            torch.cuda.empty_cache()
        except Exception:
            pass
        try:
            model.to("cpu")
            ent = sequence_entropy(text, torch.device("cpu"))
            if device.type == "cuda":
                model.to(device)
        except Exception:
            ent = float("nan")
    df.at[idx, "entropy_new"] = ent
    df.to_csv(output_path, index=False)
